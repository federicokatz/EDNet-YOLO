# %%
import tifffile as tiff
import matplotlib.pyplot as plt

# Leer el tif
img_stack = tiff.imread("./videos/MAX230426_bCatTracking_Exp91_20230426_73604 AM_f0000_t0000.tif")

# Mostrar el primer frame
plt.imshow(img_stack[0])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0..13933].
